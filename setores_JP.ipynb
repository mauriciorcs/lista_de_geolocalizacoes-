# %%
import geopandas as gpd
import matplotlib.pyplot as plt
import pandas as pd
from shapely.geometry import Point

# %%
# Mapa da Paraíba
setores_pb = gpd.read_file("PB_Setores_2021.shp")
setores_pb.plot()
# Out:
# <Axes: >

# %%
filtro_colunas = setores_pb.columns
filtro_colunas
# Out:
# Index(['CD_SETOR', 'CD_SIT', 'NM_SIT', 'CD_UF', 'NM_UF', 'SIGLA_UF', 'CD_MUN',
#        'NM_MUN', 'CD_DIST', 'NM_DIST', 'CD_SUBDIST', 'NM_SUBDIST', 'geometry'],
#       dtype='object')

# %%
# mapa de polígonos de setores censitários de João Pessoa
setores_pb = setores_pb.loc[setores_pb["NM_MUN"] == "João Pessoa"]
setores_pb.plot()
# Out:
# <Axes: >

# %%
# filtro de setores
setores_pb = setores_pb.loc[setores_pb["NM_MUN"] == "João Pessoa"]
setores_pb.head(5)
# Out:
#              CD_SETOR CD_SIT                                        NM_SIT  \
# 3836  250750705000001      1  Área Urbana de Alta Densidade de Edificações
# 3837  250750705000002      1  Área Urbana de Alta Densidade de Edificações
# 3838  250750705000003      1  Área Urbana de Alta Densidade de Edificações
# 3839  250750705000004      1  Área Urbana de Alta Densidade de Edificações
# 3840  250750705000005      1  Área Urbana de Alta Densidade de Edificações
#
#      CD_UF    NM_UF SIGLA_UF   CD_MUN       NM_MUN    CD_DIST      NM_DIST  \
# 3836    25  Paraíba       PB  2507507  João Pessoa  250750705  João Pessoa
# 3837    25  Paraíba       PB  2507507  João Pessoa  250750705  João Pessoa
# 3838    25  Paraíba       PB  2507507  João Pessoa  250750705  João Pessoa
# 3839    25  Paraíba       PB  2507507  João Pessoa  250750705  João Pessoa
# 3840    25  Paraíba       PB  2507507  João Pessoa  250750705  João Pessoa
#
#        CD_SUBDIST  NM_SUBDIST  \
# 3836  25075070500         NaN
# 3837  25075070500         NaN
# 3838  25075070500         NaN
# 3839  25075070500         NaN
# 3840  25075070500         NaN
#
#                                                geometry
# 3836  POLYGON ((-34.87387 -7.14686, -34.87373 -7.147...
# 3837  POLYGON ((-34.87459 -7.14956, -34.87479 -7.150...
# 3838  POLYGON ((-34.87424 -7.14543, -34.87492 -7.145...
# 3839  POLYGON ((-34.87264 -7.14618, -34.87330 -7.146...
# 3840  POLYGON ((-34.87048 -7.14824, -34.87059 -7.148...

# %%
setores_pb.to_csv("Setores_Joao_Pessoa_PB.csv", index=False)
